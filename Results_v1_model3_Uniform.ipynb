# %% [markdown]
# # Results model3: Uniform CIFAR with 1 Discriminator & FID logging

# %%
# import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
import torch.nn.parallel
import argparse
import matplotlib.pyplot as plt
import seaborn
import numpy as np
import random
from torch.nn.parameter import Parameter
import torch.nn.init as init
import torch.nn.functional as F
import torch
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
saved_v = '_3'

# %% [markdown]
# ### Note: this notebook contains results of one run. Compartive runs are contained in seperate notebooks

# %% [markdown]
# # Run's random seed
#
# - Fed into torch.manual_seed(manualSeed)

# %%
torch.load('/home/huawei/mas_implementation/acGAN_mnist/saved'+saved_v+'/manualSeed_v1.pt')
# Out:
# 4064

# %% [markdown]
# # Learning curve

# %%
losses_G = torch.load('/home/huawei/mas_implementation/acGAN_mnist/saved'+saved_v+'/losses_G_v1.pt')
losses_D = torch.load('/home/huawei/mas_implementation/acGAN_mnist/saved'+saved_v+'/losses_D_v1.pt')

plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(losses_G,label="G")
for i in range(0,len(losses_D)):
    plt.plot(losses_D[i],label="D"+str(i+1))
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.savefig('/home/huawei/mas_implementation/acGAN_mnist/saved'+saved_v+'/losses')

# %% [markdown]
# # Policy (curriculum) formation (not imformative for 1 Discriminator)

# %%
pis = torch.load('/home/huawei/mas_implementation/acGAN_mnist/saved'+saved_v+'/pis_v1.pt')
for idx in range(0, len(pis)):
    pis[idx] = pis[idx].cpu().numpy()
    
plt.figure(figsize=(10,5))
plt.title("D selection policy pr after T_w ")
plt.plot(pis,label="D selection policy pr")
plt.xlabel("Epoch")
plt.ylabel("D selection policy")
plt.legend()
plt.savefig('/home/huawei/mas_implementation/acGAN_mnist/saved'+saved_v+'/pis')

# %% [markdown]
# # FID

# %%
fids_1= torch.load('/home/huawei/mas_implementation/acGAN_mnist/saved_1/fids_v1.pt')
fids_2= torch.load('/home/huawei/mas_implementation/acGAN_mnist/saved_2/fids_v1.pt')
fids_3= torch.load('/home/huawei/mas_implementation/acGAN_mnist/saved_3/fids_v1.pt')

plt.figure(figsize=(10,5))
plt.title("FID score per epoch with same manual seed")
plt.plot(fids_3,label="Uniform", color = 'orange')
plt.plot(fids_2,label="FID GMAN-1", color = 'blue')
plt.plot(fids_1,label="FID acGAN", color = 'green')
plt.xlabel("Epoch")
plt.ylabel("FID score per epoch")
plt.legend()
plt.savefig('/home/huawei/mas_implementation/acGAN_mnist/saved'+saved_v+'/fids')

# %% [markdown]
# # Original Images

# %%
dataloader =  torch.load('/home/huawei/mas_implementation/acGAN_mnist/saved'+saved_v+'/dataloader_v1.pt')
device = 'cuda'
real_batch = next(iter(dataloader))

fig = plt.figure(figsize=(30,30))
fig.add_subplot(1,1,1)
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %% [markdown]
# # Generated images

# %%
img_list =  torch.load('/home/huawei/mas_implementation/acGAN_mnist/saved'+saved_v+'/img_list_v1.pt')
fig = plt.figure(figsize=(30,30))
fig.add_subplot(1,1,1)
plt.imshow(np.transpose(img_list[-1],(1,2,0)))
plt.savefig('/home/huawei/mas_implementation/acGAN_mnist/saved'+saved_v+'/fake')

# %%
len(img_list)
# Out:
# 24

# %% [markdown]
# # Machine particulars

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 158
# model name	: Intel(R) Core(TM) i7-7700 CPU @ 3.60GHz
# stepping	: 9
# microcode	: 0xca
# cpu MHz		: 4100.027
# cache size	: 8192 KB
# physical id	: 0
# siblings	: 8
# core id		: 0
# cpu cores	: 4
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 22
# wp		: yes
# ...

# %% [markdown]
# # GPU particulars

# %%
# !nvidia-smi
# Out:
# Tue Jun  9 11:32:29 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 440.82       CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 106...  Off  | 00000000:01:00.0 Off |                  N/A |
# | 37%   54C    P8     6W / 120W |   1378MiB /  6078MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...
